# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
import scipy.stats as st
import datetime

from scipy.stats import linregress
from pprint import pprint

from config import weather_api_key
from config import geoapify_key

from citipy import citipy

# %%
#read in cxv file 
resort_city_data_df = pd.read_csv("Resources/resort_cities_current.csv", index_col="City_ID")

resort_city_data_df
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                        moengo   5.6167  -54.4000     30.56        62
# 1                ribeira grande  38.5167  -28.7000     17.65        67
# 2        hawaiian paradise park  19.5933 -154.9731     21.05        93
# 3                         yaren  -0.5472  166.9160     28.05        79
# 4                         lihue  21.9789 -159.3672     20.97        89
# ...                         ...      ...       ...       ...       ...
# 4374                    tecuala  22.3986 -105.4569     31.52        29
# 4375                 swellendam -34.0226   20.4417     15.90        57
# 4376                  jalalabad  34.4265   70.4515     24.27        48
# 4377                   pho chai  16.3283  103.7703     32.68        54
# 4378                    talisay  10.2447  123.8494     28.01        83
#
#          Cloudiness  Wind Speed Country                 Date
# City_ID
# 0                77        2.59      SR  2023-04-28 10:40:29
# 1                40        9.77      PT  2023-04-28 10:40:29
# 2                 0        2.57      US  2023-04-28 10:40:29
# 3                96        6.30      NR  2023-04-28 10:40:30
# 4               100        5.14      US  2023-04-28 10:40:30
# ...             ...         ...     ...                  ...
# 4374             19        3.14      MX  2023-04-28 11:05:42
# 4375              7        2.28      ZA  2023-04-28 11:05:42
# 4376             40        0.93      AF  2023-04-28 11:05:42
# 4377             16        2.55      TH  2023-04-28 11:05:43
# 4378             20        3.09      PH  2023-04-28 11:05:43
#
# [4379 rows x 9 columns]

# %%
#set temperature perameters
resort_city_ideal_df = resort_city_data_df.loc[(resort_city_data_df["Max Temp"] < 30)
                                 & (resort_city_data_df["Max Temp"] > 24)
                                & (resort_city_data_df["Humidity"] < 70) 
                                & (resort_city_data_df["Humidity"] > 20)
                                & (resort_city_data_df["Wind Speed"] < 8)
                                & (resort_city_data_df["Cloudiness"] == 0)]
resort_city_ideal_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 41             newman  37.3138 -121.0208     27.81        45           0
# 48             laguna  38.4210 -121.4238     29.49        50           0
# 60          los altos  37.3852 -122.1141     28.10        64           0
# 88       khawr fakkan  25.3313   56.3420     29.03        53           0
# 120          umm qasr  30.0405   47.9168     29.93        24           0
#
#          Wind Speed Country                 Date
# City_ID
# 41             0.89      US  2023-04-28 10:40:44
# 48             1.54      US  2023-04-28 10:40:45
# 60             3.60      US  2023-04-28 10:38:03
# 88             4.34      AE  2023-04-28 10:40:55
# 120            3.82      IQ  2023-04-28 10:41:04

# %%
#count number of cities returned
resort_city_ideal_df.count()
# Out:
# City          186
# Lat           186
# Lng           186
# Max Temp      186
# Humidity      186
# Cloudiness    186
# Wind Speed    186
# Country       186
# Date          186
# dtype: int64

# %%
#add columns for geoapi call info to go into 
resort_city_ideal_df["Number of Hotels"] = ""
resort_city_ideal_df["Number of Resturants"] = ""
resort_city_ideal_df["Bodies of Water"] = ""
resort_city_ideal_df["Tourist Attractions"] = ""
resort_city_ideal_df["Natural Places"] = ""
resort_city_ideal_df["Hospital"] = ""
resort_city_ideal_df["Entertainment"] = ""
resort_city_ideal_df["Rental Car"] = ""
resort_city_ideal_df["Airport"] = ""

resort_city_ideal_df.head()
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Number of Hotels"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Number of Resturants"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Bodies of Water"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Tourist Attractions"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Natural Places"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Hospital"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Entertainment"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Rental Car"] = ""
# C:\Users\sarah\AppData\Local\Temp\ipykernel_24432\390181530.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   resort_city_ideal_df["Airport"] = ""
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 41             newman  37.3138 -121.0208     27.81        45           0
# 48             laguna  38.4210 -121.4238     29.49        50           0
# 60          los altos  37.3852 -122.1141     28.10        64           0
# 88       khawr fakkan  25.3313   56.3420     29.03        53           0
# 120          umm qasr  30.0405   47.9168     29.93        24           0
#
#          Wind Speed Country                 Date Number of Hotels  \
# City_ID
# 41             0.89      US  2023-04-28 10:40:44
# 48             1.54      US  2023-04-28 10:40:45
# 60             3.60      US  2023-04-28 10:38:03
# 88             4.34      AE  2023-04-28 10:40:55
# 120            3.82      IQ  2023-04-28 10:41:04
#
#         Number of Resturants Bodies of Water Tourist Attractions  \
# City_ID
# 41
# 48
# 60
# 88
# 120
#
#         Natural Places Hospital Entertainment Rental Car Airport
# City_ID
# 41
# 48
# 60
# 88
# 120

# %%
#build function for making api calls on different categories
def city_categories(categories, column, df):
    
    for index, row in df.iterrows():
        # get latitude, longitude from the DataFrame
        latitude = row["Lat"]
        longitude = row["Lng"]

        # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary

        # Set base URL
       
        radius = 16000

        # Set the parameters for the type of search
        filters = f"circle:{longitude},{latitude},{radius}"
        bias = f"proximity:{longitude},{latitude}"
        limit = 200

        # set up a parameters dictionary
        params = {
            "categories":categories,
            "limit":limit,
            "filter":filters,
            "bias":bias,
            "apiKey":geoapify_key    
        }

        # Set base URL
        base_url = "https://api.geoapify.com/v2/places"

        # run a request using our params dictionary
        response = requests.get(base_url, params=params)
        response_json = response.json()

        #pprint(response_json)


        # Grab the first hotel from the results and store the name in the hotel_df DataFrame
        try:
            df.loc[index, column] = len(response_json["features"])
        except (KeyError, IndexError):
            df.loc[index, column] = 0   
        
    return df

# %%
#find cities with airports
categories = "airport.international"
column = "Airport"
resort_city_ideal_df = city_categories(categories, column, resort_city_ideal_df)

# %%
#drop cities with no airports
cities_airports = resort_city_ideal_df[(resort_city_ideal_df[["Airport"]] != 0).all(axis=1)]

# %%
#find hotels and resorts in each city
categories = "accommodation, beach.beach_resort"
column = "Number of Hotels"
ideal_cities_all_df = city_categories(categories, column, cities_airports)

# %%
#limit the number of hotels we want in each location 
resort_city_sorted = ideal_cities_all_df.sort_values("Number of Hotels")

cities_airports_hotel_lim = resort_city_sorted[(resort_city_sorted["Number of Hotels"] <= 25)]

# %%
#print dataframe
cities_airports_hotel_lim
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 4053                  khark  29.2614   50.3306     26.32        54
# 41                   newman  37.3138 -121.0208     27.81        45
# 251              dogonbadan  30.3586   50.7981     24.05        29
# 429                 al wajh  26.2455   36.4525     25.97        65
# 733                al awjam  26.5632   49.9433     28.06        34
# 2604     santana do paraiso -19.3636  -42.5686     28.18        51
# 2329              brownwood  31.7093  -98.9912     25.00        57
# 608             al kharijah  25.4514   30.5464     25.47        23
# 3633                   goya -29.1400  -59.2626     28.96        31
# 465                alegrete -29.7831  -55.7919     27.34        30
# 1720         treinta y tres -33.2333  -54.3833     27.40        35
# 947       francisco beltrao -26.0811  -53.0550     24.12        52
# 1168                zachary  30.6485  -91.1565     26.52        51
# 4230         general pinedo -27.3167  -61.2833     28.23        50
# 3779                artigas -30.4000  -56.4667     27.63        30
# 3644            miandrivazo -19.5167   45.4667     25.74        59
# 2112                 quarai -30.3875  -56.4514     27.69        30
# 2293             tacuarembo -31.7333  -55.9833     28.39        28
# 2594                    hun  29.1268   15.9477     25.69        23
# 2403           santo angelo -28.2992  -54.2631     26.18        57
# 3010              patterson  37.4716 -121.1297     28.34        41
# 1417            nacogdoches  31.6002  -94.6335     24.76        64
# 3357                 diboll  31.1871  -94.7810     25.68        59
# 2565               omidiyeh  30.7597   49.7050     29.93        28
# 766                aghajari  30.7006   49.8315     29.12        28
# 4010                carmelo -33.9892  -58.2856     27.58        34
# 2886                 itaqui -29.1253  -56.5531     28.29        27
# 2579                 rivera -30.9053  -55.5508     26.77        31
# 2832            haines city  28.1142  -81.6179     29.34        69
# 3510             dar kulayb  26.0686   50.5039     28.09        52
# 4129     paso de los libres -29.7131  -57.0899     28.02        44
# 776                vallenar -28.5708  -70.7581     25.15        36
# 3604              la marque  29.3686  -94.9713     29.49        61
#
#          Cloudiness  Wind Speed Country                 Date Number of Hotels  \
# City_ID
# 4053              0        2.94      IR  2023-04-28 11:03:50                0
# 41                0        0.89      US  2023-04-28 10:40:44                1
# 251               0        2.06      IR  2023-04-28 10:41:52                1
# 429               0        4.63      SA  2023-04-28 10:42:53                1
# 733               0        3.60      SA  2023-04-28 10:44:40                2
# %%
#find tourist attractions present in cities 
categories = "tourism"
column = "Tourist Attractions"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#find resturants present locations 
categories = "catering.restaurant"
column = "Number of Resturants"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#find natural areas in locations 
categories = "natural"
column = "Natural Places"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#find hospitals in locations 
categories = "healthcare.hospital"
column = "Hospital"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#find rental car agencies in locations 
categories = "rental.car"
column = "Rental Car"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#find entertainment opportunties in locations 
categories = "entertainment"
column = "Entertainment"
ideal_cities_all_df = city_categories(categories, column, cities_airports_hotel_lim)

# %%
#print df
cities_airports_hotel_lim
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 4053                  khark  29.2614   50.3306     26.32        54
# 41                   newman  37.3138 -121.0208     27.81        45
# 251              dogonbadan  30.3586   50.7981     24.05        29
# 429                 al wajh  26.2455   36.4525     25.97        65
# 733                al awjam  26.5632   49.9433     28.06        34
# 2604     santana do paraiso -19.3636  -42.5686     28.18        51
# 2329              brownwood  31.7093  -98.9912     25.00        57
# 608             al kharijah  25.4514   30.5464     25.47        23
# 3633                   goya -29.1400  -59.2626     28.96        31
# 465                alegrete -29.7831  -55.7919     27.34        30
# 1720         treinta y tres -33.2333  -54.3833     27.40        35
# 947       francisco beltrao -26.0811  -53.0550     24.12        52
# 1168                zachary  30.6485  -91.1565     26.52        51
# 4230         general pinedo -27.3167  -61.2833     28.23        50
# 3779                artigas -30.4000  -56.4667     27.63        30
# 3644            miandrivazo -19.5167   45.4667     25.74        59
# 2112                 quarai -30.3875  -56.4514     27.69        30
# 2293             tacuarembo -31.7333  -55.9833     28.39        28
# 2594                    hun  29.1268   15.9477     25.69        23
# 2403           santo angelo -28.2992  -54.2631     26.18        57
# 3010              patterson  37.4716 -121.1297     28.34        41
# 1417            nacogdoches  31.6002  -94.6335     24.76        64
# 3357                 diboll  31.1871  -94.7810     25.68        59
# 2565               omidiyeh  30.7597   49.7050     29.93        28
# 766                aghajari  30.7006   49.8315     29.12        28
# 4010                carmelo -33.9892  -58.2856     27.58        34
# 2886                 itaqui -29.1253  -56.5531     28.29        27
# 2579                 rivera -30.9053  -55.5508     26.77        31
# 2832            haines city  28.1142  -81.6179     29.34        69
# 3510             dar kulayb  26.0686   50.5039     28.09        52
# 4129     paso de los libres -29.7131  -57.0899     28.02        44
# 776                vallenar -28.5708  -70.7581     25.15        36
# 3604              la marque  29.3686  -94.9713     29.49        61
#
#          Cloudiness  Wind Speed Country                 Date Number of Hotels  \
# City_ID
# 4053              0        2.94      IR  2023-04-28 11:03:50                0
# 41                0        0.89      US  2023-04-28 10:40:44                1
# 733                 36       10             0          0       1
# 2604               106       10             1          0       1
# 2329                22        1             1          0       1
# 608                 26        1             0          0       1
# 3633               200        4             2          0       3
# 465                 47        2             1          0       1
# 1720                53        4             4          0       1
# 947                200        7             2          0       1
# 1168                95        1            10          0       1
# 4230                10        4             2          0       1
# 3779                52        5             2          0       1
# 3644                28        0             0          0       1
# 2112                50        5             2          0       1
# 2293                55        1             2          1       1
# 2594                 8        2             0          0       1
# 2403               107        5            13          0       1
# 3010               200        0             3          0       1
# 1417                98        2             6          1       1
# 3357                87        1             4          0       1
# 2565                27        3             8          0       2
# 766                 64        3             8          0       1
# 4010               133        1             5          0       1
# 2886               107        6             1          0       1
# 2579                24        5             1          0       1
# 2832               200        3             9          4       1
# 3510               200       11             9          8       1
# 4129               110        6             5          0       3
# 776                 29        2             3          0       1
# 3604               200        1             6          0       1

# %%
#sort by hotels 
cities_sorted_by_hotels = cities_airports.sort_values("Number of Hotels", ascending=True)

cities_sorted_by_hotels
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4053              khark  29.2614   50.3306     26.32        54           0
# 41               newman  37.3138 -121.0208     27.81        45           0
# 251          dogonbadan  30.3586   50.7981     24.05        29           0
# 429             al wajh  26.2455   36.4525     25.97        65           0
# 733            al awjam  26.5632   49.9433     28.06        34           0
# ...                 ...      ...       ...       ...       ...         ...
# 2968             caxias  38.7031   -9.2767     26.90        47           0
# 4018              dubai  25.2582   55.3047     27.14        61           0
# 2473           paysandu -32.3214  -58.0756     27.00        38           0
# 1536           trujillo  -8.1160  -79.0300     26.98        65           0
# 4164     west hollywood  34.0900 -118.3617     29.60        66           0
#
#          Wind Speed Country                 Date Number of Hotels  \
# City_ID
# 4053           2.94      IR  2023-04-28 11:03:50                0
# 41             0.89      US  2023-04-28 10:40:44                1
# 251            2.06      IR  2023-04-28 10:41:52                1
# 429            4.63      SA  2023-04-28 10:42:53                1
# 733            3.60      SA  2023-04-28 10:44:40                2
# ...             ...     ...                  ...              ...
# 2968           6.17      PT  2023-04-28 10:57:30              200
# 4018           2.57      AE  2023-04-28 11:01:57              200
# 2473           6.61      UY  2023-04-28 10:52:41              200
# 1536           5.14      PE  2023-04-28 10:50:33              200
# 4164           4.63      US  2023-04-28 11:02:47              200
#
#         Number of Resturants Bodies of Water Tourist Attractions  \
# City_ID
# 4053
# 41
# 251
# 429
# 733
# ...                      ...             ...                 ...
# 2968
# 4018
# 2473
# 1536
# 4164
#
#         Natural Places Hospital Entertainment Rental Car Airport
# City_ID
# 4053                                                           1
# 41                                                             1
# 251                                                            1
# 429                                                            1
# 733                                                            1
# ...                ...      ...           ...        ...     ...
# 2968                                                           2
# 4018                                                           1
# 2473                                                           1
# 1536                                                           1
# 4164                                                           3
#
# [66 rows x 18 columns]

# %%
#eport to csv 
cities_airports_hotel_lim.to_csv("Resources/cities_airports_hotel_lim.csv", index_label="City_ID")
